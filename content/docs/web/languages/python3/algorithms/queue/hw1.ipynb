# %% [markdown]
# - 修改中缀转后缀算法，使其能够处理错误。
# - 修改后缀表达式求值算法，使其能够处理错误。
# - 实现一个直接中缀表达式求值器，该求值器结合了中缀转后缀的转换功能和后缀表达式求值算法。你的求值器应从左到右处理中缀标记，并使用两个栈（一个用于运算符，一个用于操作数）来执行求值操作。
# - 将上一题中的直接中缀表达式求值器改造成一个计算器。
# - 实现Queue抽象数据类型（ADT），使用列表，使得队列的尾部位于列表的末尾。
# - 设计并实施一项实验，对这两种队列实现进行基准比较。从这样的实验中你能学到什么？
# - 可以实现一个队列，使得入队和出队操作的平均时间复杂度为O(1)。在这种情况下，这意味着大多数时候入队和出队操作的时间复杂度都是O(1)，但在一种特定情况下，出队操作的时间复杂度会变为O(n)。
# - 试想一个现实生活中的场景。提出一个问题，然后设计一个模拟实验来帮助回答这个问题。可能的场景包括：
#   - 洗车处排队的汽车
#   - 杂货店收银台前的顾客
#   - 在跑道上起飞和降落的飞机
#   - 银行柜员
#   请务必说明您所做的任何假设，并提供作为该场景一部分必须考虑的任何概率数据。
# - 修改“烫手山芋”模拟，使其能够随机选择一个计数数值，这样每次传递都无法根据前一次传递来预测。
# - 实现一个基数排序机。针对10进制整数的基数排序是一种机械排序技术，它使用一组容器，包括1个主容器和10个数字容器。每个容器的作用类似队列，按元素到达的顺序保存它们的值。该算法首先将每个数字放入主容器中。然后，它逐位处理每个数值。取出第一个数值，将其放入与当前所处理数字对应的数字容器中。例如，如果处理的是个位数字，534会被放入数字容器4，667会被放入数字容器7。当所有数值都放入相应的数字容器后，从容器0到容器9依次收集数值，并将它们放回主容器。之后，继续对十位、百位等数字进行这一过程。在处理完最后一位数字后，主容器中的数值就处于有序状态了。
# - 括号匹配问题的另一个例子来自超文本标记语言（HTML）。在HTML中，标签有开始和结束两种形式，且必须保持平衡才能正确描述一个网页文档。编写一个程序，能够检查HTML文档中标签的正确打开和关闭情况。
# ```python
# <html>
#    <head>
#       <title>
#          Example
#       </title>
#    </head>
#
#    <body>
#       <h1>Hello, world</h1>
#    </body>
# </html>
# ```
# - 扩展清单2.15中的程序，使其能够处理包含空格的回文。例如，“I PREFER PI”就是一个回文，若忽略其中的空格字符，那么它从前往后和从后往前读是一样的。
# - 为了实现length方法，我们统计了列表中的节点数量。另一种策略是将列表中的节点数量作为额外数据存储在列表的头部。修改UnorderedList类以包含此信息，并重新编写length方法。
# - 实现remove方法，使其在列表中不存在该元素的情况下也能正确工作。
# - 修改列表类以允许重复项。这一变化会影响哪些方法？
# - 在UnorderedList类中实现__str__方法。一个列表的良好字符串表示形式会是什么样的呢？
# - 实现 __str__ 方法，以便列表以 Python 的方式显示（带有方括号）。
# - 实现无序列表抽象数据类型（UnorderedList ADT）中定义的其余操作（append、index、pop、insert）。
# - 为UnorderedList类实现一个切片方法。该方法应接受两个参数start和stop，并返回列表的一个副本，该副本从start位置开始，一直到但不包括stop位置。
# - 实现有序列表抽象数据类型中定义的其余操作。
# - 思考无序列表和有序列表之间的关系。是否可以使用继承来构建更高效的实现？实现这个继承层次结构。
# - 使用链表实现一个栈。
# - 用链表实现一个队列。
# - 使用链表实现双端队列。
# - 设计并实施一项实验，用于比较Python列表与以链表形式实现的列表的性能。
# - 设计并实施一项实验，以比较基于Python列表的栈和队列与链表实现的性能。
# - 上面给出的链表实现被称为单向链表，因为每个节点只有一个指向序列中下一个节点的引用。另一种实现被称为双向链表。在这种实现中，每个节点都有一个指向 next 节点的引用（通常称为 next），以及一个指向前一个节点的引用（通常称为 back）。头引用也包含两个引用，一个指向链表中的第一个节点，另一个指向最后一个节点。用 Python 编写这种实现。
# - 创建一个队列的实现，使其入队和出队操作的平均性能达到O(1)。
